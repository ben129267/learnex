# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_fake=pd.read_csv(r"C:\Users\REGY PHILIP\Desktop\my projects\BuzzFeed_fake_news_content.csv")

# %%
df_fake.head()
# Out:
#                 id                                              title  \
# 0   Fake_1-Webpage  Proof The Mainstream Media Is Manipulating The...
# 1  Fake_10-Webpage  Charity: Clinton Foundation Distributed “Water...
# 2  Fake_11-Webpage  A Hillary Clinton Administration May be Entire...
# 3  Fake_12-Webpage  Trump’s Latest Campaign Promise May Be His Mos...
# 4  Fake_13-Webpage                    Website is Down For Maintenance
#
#                                                 text  \
# 0  I woke up this morning to find a variation of ...
# 1  Former President Bill Clinton and his Clinton ...
# 2  After collapsing just before trying to step in...
# 3  Donald Trump is, well, deplorable. He’s sugges...
# 4                    Website is Down For Maintenance
#
#                                                  url  \
# 0  http://www.addictinginfo.org/2016/09/19/proof-...
# 1  http://eaglerising.com/36899/charity-clinton-f...
# 2  http://eaglerising.com/36880/a-hillary-clinton...
# ...

# %%
df_true=pd.read_csv(r"C:\Users\REGY PHILIP\Desktop\my projects\BuzzFeed_real_news_content.csv")

# %%
df_true.head()
# Out:
#                 id                                              title  \
# 0   Real_1-Webpage  Another Terrorist Attack in NYC…Why Are we STI...
# 1  Real_10-Webpage  Donald Trump: Drugs a 'Very, Very Big Factor' ...
# 2  Real_11-Webpage  Obama To UN: ‘Giving Up Liberty, Enhances Secu...
# 3  Real_12-Webpage  Trump vs. Clinton: A Fundamental Clash over Ho...
# 4  Real_13-Webpage  President Obama Vetoes 9/11 Victims Bill, Sett...
#
#                                                 text  \
# 0  On Saturday, September 17 at 8:30 pm EST, an e...
# 1  Less than a day after protests over the police...
# 2  Obama To UN: ‘Giving Up Liberty, Enhances Secu...
# 3  Getty Images Wealth Of Nations Trump vs. Clint...
# 4  President Obama today vetoed a bill that would...
#
#                                                  url  \
# 0  http://eaglerising.com/36942/another-terrorist...
# 1                             http://abcn.ws/2d4lNn9
# 2  http://rightwingnews.com/barack-obama/obama-un...
# ...

# %%
df_fake["class"]=0
df_true["class"]=1

# %%
df_fake.shape,df_true.shape
# Out:
# ((91, 13), (91, 13))

# %%
df_merge=pd.concat([df_fake,df_true])
print(df_merge)
# Out:
#                  id                                              title  \
# 0    Fake_1-Webpage  Proof The Mainstream Media Is Manipulating The...
# 1   Fake_10-Webpage  Charity: Clinton Foundation Distributed “Water...
# 2   Fake_11-Webpage  A Hillary Clinton Administration May be Entire...
# 3   Fake_12-Webpage  Trump’s Latest Campaign Promise May Be His Mos...
# 4   Fake_13-Webpage                    Website is Down For Maintenance
# ..              ...                                                ...
# 86  Real_88-Webpage  It’s “Trump is HITLER” Month at the Washington...
# 87  Real_89-Webpage       Obama’s team isn’t laughing at Trump anymore
# 88   Real_9-Webpage  Georgia poll: Donald Trump, Hillary Clinton in...
# 89  Real_90-Webpage  Chelsea Handler Gets The Last Word After RNC C...
# 90  Real_91-Webpage         Is Donald Trump qualified to be president?
#
#                                                  text  \
# 0   I woke up this morning to find a variation of ...
# ...

# %%
df_merge.head(10)
# Out:
#                 id                                              title  \
# 0   Fake_1-Webpage  Proof The Mainstream Media Is Manipulating The...
# 1  Fake_10-Webpage  Charity: Clinton Foundation Distributed “Water...
# 2  Fake_11-Webpage  A Hillary Clinton Administration May be Entire...
# 3  Fake_12-Webpage  Trump’s Latest Campaign Promise May Be His Mos...
# 4  Fake_13-Webpage                    Website is Down For Maintenance
# 5  Fake_14-Webpage                  Obama Pushes One World Government
# 6  Fake_15-Webpage  Clinton Foundation Spent 5.7% on Charity; Rest...
# 7  Fake_16-Webpage  WHOA! NEW DISTURBING VIDEO Shows HILLARY'S Cam...
# 8  Fake_17-Webpage  Is it the Beginning of the End for Hillary Cli...
# 9  Fake_18-Webpage  Californians Had Special Way to View the Eclip...
#
#                                                 text  \
# 0  I woke up this morning to find a variation of ...
# 1  Former President Bill Clinton and his Clinton ...
# ...

# %%
df_merge.columns
# Out:
# Index(['id', 'title', 'text', 'url', 'top_img', 'authors', 'source',
#        'publish_date', 'movies', 'images', 'canonical_link', 'meta_data',
#        'class'],
#       dtype='object')

# %%
data=df_merge.drop(['title','movies','publish_date','images','top_img','canonical_link','authors'],axis=1)

# %%
data.isnull().sum()
# Out:
# id           0
# text         0
# url          8
# source       8
# meta_data    0
# class        0
# dtype: int64

# %%
data.fillna(0,inplace=True)

# %%
data.isnull().sum()
# Out:
# id           0
# text         0
# url          0
# source       0
# meta_data    0
# class        0
# dtype: int64

# %%
data.head(10)
# Out:
#                 id                                               text  \
# 0   Fake_1-Webpage  I woke up this morning to find a variation of ...
# 1  Fake_10-Webpage  Former President Bill Clinton and his Clinton ...
# 2  Fake_11-Webpage  After collapsing just before trying to step in...
# 3  Fake_12-Webpage  Donald Trump is, well, deplorable. He’s sugges...
# 4  Fake_13-Webpage                    Website is Down For Maintenance
# 5  Fake_14-Webpage  When President Obama spoke at the United Natio...
# 6  Fake_15-Webpage  Back when the news first broke about the pay-t...
# 7  Fake_16-Webpage  On September 15, Hillary “apparently” held a r...
# 8  Fake_17-Webpage  I can’t wait for “Weekend at Chelsea’s” to hit...
# 9  Fake_18-Webpage  Olympic Committee Buckles to LGBT Groups... Ma...
#
#                                                  url  \
# 0  http://www.addictinginfo.org/2016/09/19/proof-...
# 1  http://eaglerising.com/36899/charity-clinton-f...
# ...

# %%
data.tail(10)
# Out:
#                  id                                               text  \
# 81  Real_83-Webpage  CLEVELAND — Donald Trump campaigned Wednesday ...
# 82  Real_84-Webpage  “He didn’t say the document was legitimate," J...
# 83  Real_85-Webpage  Story highlights Obama has taken steps toward ...
# 84  Real_86-Webpage  Story highlights Virginia Gov. Terry McAuliffe...
# 85  Real_87-Webpage  In March, in a bold “Oh yeah?” moment during a...
# 86  Real_88-Webpage  Like much of the mainstream media, the Washing...
# 87  Real_89-Webpage  2016 Obama’s team isn’t laughing at Trump anym...
# 88   Real_9-Webpage  Story highlights Trump has 45%, Clinton 42% an...
# 89  Real_90-Webpage  There may be a few women out there who enjoy a...
# 90  Real_91-Webpage  Off Message Is Donald Trump qualified to be pr...
#
#                                                   url  \
# 81                           http://politi.co/2cRQmvU
# 82                           http://politi.co/2cLospd
# ...

# %%
data.columns
# Out:
# Index(['id', 'text', 'url', 'source', 'meta_data', 'class'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 0 to 90
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         182 non-null    object
#  1   text       182 non-null    object
#  2   url        182 non-null    object
#  3   source     182 non-null    object
#  4   meta_data  182 non-null    object
#  5   class      182 non-null    int64
# dtypes: int64(1), object(5)
# memory usage: 10.0+ KB

# %%
data.columns
# Out:
# Index(['id', 'text', 'url', 'source', 'meta_data', 'class'], dtype='object')

# %%
data.columns
# Out:
# Index(['id', 'text', 'url', 'source', 'meta_data', 'class'], dtype='object')

# %%
X=data['text']
y=data['class']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print('Train set:',X_train.shape,y_train.shape)
print('Test set:',X_test.shape,y_train.shape)
# Out:
# Train set: (145,) (145,)
# Test set: (37,) (145,)

# %%
vectorizer = TfidfVectorizer(max_features=1000) 
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
svc = SVC(kernel='linear')
svc.fit(X_train_tfidf, y_train)
# Out:
# SVC(kernel='linear')

# %%
accuracy = svc.score(X_test_tfidf, y_test)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.86
